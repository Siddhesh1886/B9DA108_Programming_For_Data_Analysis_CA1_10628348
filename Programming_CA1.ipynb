# %%
import requests
resp=requests.get('http://metwdb-openaccess.ichec.ie/metno-wdb2ts/locationforecast?lat=54.7210798611;long=-8.7237392806')

# %%
resp.content
# Out:
# b'<weatherdata xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:noNamespaceSchemaLocation="http://api.met.no/weatherapi/locationforecast/1.9/schema" created="2022-11-28T11:46:25Z">\n   <meta>\n      <model name="harmonie" termin="2022-11-28T06:00:00Z" runended="2022-11-28T08:49:45Z" nextrun="2022-11-28T16:00:00Z" from="2022-11-28T12:00:00Z" to="2022-11-30T12:00:00Z" />\n      <model name="ec_n1280_1hr" termin="2022-11-28T00:00:00Z" runended="2022-11-28T08:49:44Z" nextrun="2022-11-28T18:00:00Z" from="2022-11-30T13:00:00Z" to="2022-12-01T18:00:00Z" />\n      <model name="ec_n1280_3hr" termin="2022-11-28T00:00:00Z" runended="2022-11-28T08:49:44Z" nextrun="2022-11-28T18:00:00Z" from="2022-12-01T21:00:00Z" to="2022-12-04T00:00:00Z" />\n      <model name="ec_n1280_6hr" termin="2022-11-28T00:00:00Z" runended="2022-11-28T08:49:44Z" nextrun="2022-11-28T18:00:00Z" from="2022-12-04T06:00:00Z" to="2022-12-08T00:00:00Z" />\n      </meta>\n   <product class="pointData">\n      <time datatype="forecast" from="2022-11-28T12:00:00Z" to="2022-11-28T12:00:00Z">\n         <location altitude="9" latitude="54.7211" longitude="-8.7237">\n            <temperature id="TTT" unit="celsius" value="10.2"/>\n            <windDirection id="dd" deg="304.4" name="NW"/>\n            <windSpeed id="ff" mps="7.1" beaufort="4" name="Laber bris"/>\n            <windGust id="ff_gust" mps="10.5"/>\n            <globalRadiation value="116.4" unit="W/m^2"/>\n            <humidity value="72.8" unit="percent"/>\n            <pressure id="pr" unit="hPa" value="1008.0"/>\n            <cloudiness id="NN" percent="90.3"/>\n            <lowClouds id="LOW" percent="90.3"/>\n            <mediumClouds id="MEDIUM" percent="0.0"/>\n            <highClouds id="HIGH" percent="0.0"/>\n            <dewpointTemperature id="TD" unit="celsius" value="5.5"/>\n         </location>\n      </time>\n      <time datatype="forecast" from="2022-11-28T11:00:00Z" to="2022-11-28T12:00:00Z">\n         <location altitude="9" latitude="54.7211" longitude="-8.7237">\n            <precipitation unit="mm" value="0.0" minvalue="0.0" maxvalue="0.0" probability="0.0"/>\n<symbol id="Cloud" number="4"/>\n         </location>\n      </time>\n      <time datatype="forecast" from="2022-11-28T13:00:00Z" to="2022-11-28T13:00:00Z">\n         <location altitude="9" latitude="54.7211" longitude="-8.7237">\n            <temperature id="TTT" unit="celsius" value="10.3"/>\n            <windDirection id="dd" deg="310.7" name="NW"/>\n            <windSpeed id="ff" mps="6.4" beaufort="4" name="Laber bris"/>\n            <windGust id="ff_gust" mps="10.1"/>\n            <globalRadiation value="132.6" unit="W/m^2"/>\n            <humidity value="74.0" unit="percent"/>\n            <pressure id="pr" unit="hPa" value="1008.5"/>\n            <cloudiness id="NN" percent="28.0"/>\n            <lowClouds id="LOW" percent="28.0"/>\n            <mediumClouds id="MEDIUM" percent="0.0"/>\n            <highClouds id="HIGH" percent="0.0"/>\n            <dewpointTemperature id="TD" unit="celsius" value="5.8"/>\n         </location>\n      </time>\n      <time datatype="forecast" from="2022-11-28T12:00:00Z" to="2022-11-28T13:00:00Z">\n         <location altitude="9" latitude="54.7211" longitude="-8.7237">\n            <precipitation unit="mm" value="0.0" minvalue="0.0" maxvalue="0.0" probability="0.0"/>\n<symbol id="LightCloud" number="2"/>\n         </location>\n      </time>\n      <time datatype="forecast" from="2022-11-28T14:00:00Z" to="2022-11-28T14:00:00Z">\n         <location altitude="9" latitude="54.7211" longitude="-8.7237">\n            <temperature id="TTT" unit="celsius" value="10.4"/>\n            <windDirection id="dd" deg="314.8" name="NW"/>\n            <windSpeed id="ff" mps="5.6" beaufort="4" name="Laber bris"/>\n            <windGust id="ff_gust" mps="9.8"/>\n            <globalRadiation value="128.9" unit="W/m^2"/>\n            <humidity value="71.7" unit="percent"/>\n            <pressure id="pr" unit="hPa"  ...

# %%
import pandas as pd

# %%
index=pd.read_xml(resp.content,xpath='./product/*')

# %%
location=pd.read_xml(resp.content,xpath='./product/time/*')

# %%
df=pd.concat([index,location],axis=1).drop(['location'],axis=1)

# %%
df
# Out:
#      datatype                  from                    to  altitude  latitude  \
# 0    forecast  2022-11-28T12:00:00Z  2022-11-28T12:00:00Z         9   54.7211
# 1    forecast  2022-11-28T11:00:00Z  2022-11-28T12:00:00Z         9   54.7211
# 2    forecast  2022-11-28T13:00:00Z  2022-11-28T13:00:00Z         9   54.7211
# 3    forecast  2022-11-28T12:00:00Z  2022-11-28T13:00:00Z         9   54.7211
# 4    forecast  2022-11-28T14:00:00Z  2022-11-28T14:00:00Z         9   54.7211
# ..        ...                   ...                   ...       ...       ...
# 221  forecast  2022-12-07T06:00:00Z  2022-12-07T12:00:00Z         9   54.7211
# 222  forecast  2022-12-07T18:00:00Z  2022-12-07T18:00:00Z         9   54.7211
# 223  forecast  2022-12-07T12:00:00Z  2022-12-07T18:00:00Z         9   54.7211
# 224  forecast  2022-12-08T00:00:00Z  2022-12-08T00:00:00Z         9   54.7211
# 225  forecast  2022-12-07T18:00:00Z  2022-12-08T00:00:00Z         9   54.7211
#
#      longitude  temperature  windDirection  windSpeed  windGust  \
# 0      -8.7237          NaN            NaN        NaN       NaN
# 1      -8.7237          NaN            NaN        NaN       NaN
# 2      -8.7237          NaN            NaN        NaN       NaN
# 3      -8.7237          NaN            NaN        NaN       NaN
# 4      -8.7237          NaN            NaN        NaN       NaN
# ..         ...          ...            ...        ...       ...
# 221    -8.7237          NaN            NaN        NaN       NaN
# 222    -8.7237          NaN            NaN        NaN       NaN
# 223    -8.7237          NaN            NaN        NaN       NaN
# 224    -8.7237          NaN            NaN        NaN       NaN
# 225    -8.7237          NaN            NaN        NaN       NaN
#
#      globalRadiation  humidity  pressure  cloudiness  lowClouds  mediumClouds  \
# 0                NaN       NaN       NaN         NaN        NaN           NaN
# 1                NaN       NaN       NaN         NaN        NaN           NaN
# 2                NaN       NaN       NaN         NaN        NaN           NaN
# 3                NaN       NaN       NaN         NaN        NaN           NaN
# 4                NaN       NaN       NaN         NaN        NaN           NaN
# ..               ...       ...       ...         ...        ...           ...
# 221              NaN       NaN       NaN         NaN        NaN           NaN
# 222              NaN       NaN       NaN         NaN        NaN           NaN
# 223              NaN       NaN       NaN         NaN        NaN           NaN
# 224              NaN       NaN       NaN         NaN        NaN           NaN
# 225              NaN       NaN       NaN         NaN        NaN           NaN
#
#      highClouds  dewpointTemperature  precipitation  symbol
# 0           NaN                  NaN            NaN     NaN
# 1           NaN                  NaN            NaN     NaN
# 2           NaN                  NaN            NaN     NaN
# 3           NaN                  NaN            NaN     NaN
# 4           NaN                  NaN            NaN     NaN
# ..          ...                  ...            ...     ...
# 221         NaN                  NaN            NaN     NaN
# 222         NaN                  NaN            NaN     NaN
# 223         NaN                  NaN            NaN     NaN
# 224         NaN                  NaN            NaN     NaN
# 225         NaN                  NaN            NaN     NaN
#
# [226 rows x 20 columns]
